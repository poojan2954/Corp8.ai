# %%
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyBPtOkF0_uCZ1P8T-3kSOi9VCTguSY_9nU"

# %%
# !pip install -q youtube-transcript-api langchain-community langchain-google-genai langchain_openai faiss-cpu tiktoken python-dotenv

# %%
pip install -U langchain-huggingface
# Out:
# Requirement already satisfied: langchain-huggingface in c:\users\poojan\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.65 in c:\users\poojan\anaconda3\lib\site-packages (from langchain-huggingface) (0.3.66)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\poojan\anaconda3\lib\site-packages (from langchain-huggingface) (0.21.0)
# Requirement already satisfied: huggingface-hub>=0.30.2 in c:\users\poojan\anaconda3\lib\site-packages (from langchain-huggingface) (0.33.0)
# Requirement already satisfied: filelock in c:\users\poojan\anaconda3\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\poojan\anaconda3\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\poojan\anaconda3\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\poojan\anaconda3\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (6.0.1)
# Requirement already satisfied: requests in c:\users\poojan\anaconda3\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\poojan\anaconda3\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\poojan\anaconda3\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (4.11.0)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\poojan\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.4.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\poojan\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\poojan\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (1.33)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\poojan\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (2.8.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\poojan\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\poojan\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\poojan\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\poojan\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\poojan\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\poojan\anaconda3\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\poojan\anaconda3\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\poojan\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\poojan\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\poojan\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\poojan\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (2024.12.14)
# Requirement already satisfied: colorama in c:\users\poojan\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.30.2->langchain-huggingface) (0.4.6)
# Requirement already satisfied: anyio in c:\users\poojan\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\poojan\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\poojan\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\poojan\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Importing Libraries

# %%
from youtube_transcript_api import YouTubeTranscriptApi , TranscriptsDisabled
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate

# %% [markdown]
# #### step 1(a) Indexing

# %%
video_id = "wQGOYnWHnto";
try:
    transcript_list = YouTubeTranscriptApi.get_transcript(video_id,languages=["en"])
    transcript = " ".join(chunk["text"] for chunk in transcript_list)
    print(transcript)
except TranscriptsDisabled:
    print("No caption available for provided video")
# Out:
# this was one of the biggest days of my podcasting career that's the magic of naal ravikant Nal rant Nal ravikant founder of Angel Del no rikan Naro rakan the founder of angelist which is a giant business I mean Global I I wonder if you've ever thought of that reality if your parents didn't leave India and go to the US how would your life be different according to you the first time I used an Apple computer it was an old Macintosh I just fell in love with it at some point if you have high agency you will end up where you're meant to go it's just going to take some effort did it do anything for your mind I kind of sometimes have these near-death exercises where it's just like I imagine myself dying it's like you can see things fading out they call orgasm the petite more The Little Death right did you ever smoke weed you know I live in California well the common belief now is that like mushrooms are harmless right they're not do you miss your childhood I don't have a it's like a dream is it real actually happened B has had a great saying in every human there is a sense that something infinite has been lost wow has marriage brought further understanding when it comes to life there's a secret to a happy relationship is to happy people you know what I've learned about marriage one's wife is always right and that's the rule one should follow yes I reject that completely uh yeah people say like happy wife happy life that's all propaganda that's all feminine propaganda you're being brainwashed no both people have to be equally happy really you know from the outside looking in I personally have this impression of Naval rikan the brand and the human and I feel like nothing hurts that guy I'm a very paranoid person so my rule is I don't fight with people if somebody wants to fight with me we get one fight and then it's over there's a lot of people out there and life is long do you pray if you are older in life and you don't have the Next Generation to look forward to then you better find God fast because I don't think like your own mind and your own life will be kind to you as you get older if you know who Naval ravikant is please head straight into the conversation this intro is primarily crafted for those of you who are being introduced to Naval ravikant for the first time surprisingly there's a lot of people in India who are yet to be introduced to who I consider to be the greatest philosopher of our times I genuinely believe that history will remember him as one of the greatest Minds that lived in the 21st century he's an extremely humble extremely relaxed individual so I know that this intro is going to bother him on some level that's the side of Naval that I got to know through this conversation this is the most casual conversation that the internet has ever seen with this man it was one of the biggest honors of my own podcasting career to be sharing screen space and podcasting space with Naval ravikant if I had to introduce him professionally of course I'd tell you how he's one of the most iconic Angel Investors in the world of course i' tell you about how he's one of the most important thought leaders for Silicon Valley and the world of Global Twitter or X it's Naval ravikant on the RV show this is one of the most memorable episodes for me on a personal level but if you're looking for depth in conversation it doesn't get deeper than Naval rikan's mind it's Naval on TRS huge day for my career honestly huge day for my own Human Experience enjoy the [Music] episode this is one of the biggest days of my podcasting career but I'm also feeling supremely comfortable that's the magic of Nel ravian oh you're very nice welcome to the ren show sir thank you thanks for having me uh visualize this moment so much over the years so as I told you in the car ride on the way here uh I'm full of gratitude and as we go forward in this conversation I'm going to pour more and more gratitude on you uh when we were on our way here from the network state  ...

# %%
transcript_list
# Out:
# [{'text': 'this was one of the biggest days of my',
#   'start': 0.12,
#   'duration': 2.72},
#  {'text': "podcasting career that's the magic of",
#   'start': 1.36,
#   'duration': 4.88},
#  {'text': 'naal ravikant Nal rant Nal ravikant',
#   'start': 2.84,
#   'duration': 7.56},
#  {'text': 'founder of Angel Del no rikan Naro rakan',
#   'start': 6.24,
#   'duration': 6.04},
#  {'text': 'the founder of angelist which is a giant',
#   'start': 10.4,
#   'duration': 4.359},
#  {'text': 'business I mean Global I I wonder if',
#   'start': 12.28,
#   'duration': 3.96},
#  {'text': "you've ever thought of that reality if",
#   'start': 14.759,
#   'duration': 3.36},
#  {'text': "your parents didn't leave India and go",
#   'start': 16.24,
#   'duration': 3.4},
#  {'text': 'to the US how would your life be',
#   'start': 18.119,
#   'duration': 2.681},
#  {'text': 'different according to you the first',
#   'start': 19.64,
#   'duration': 3.08},
#  {'text': 'time I used an Apple computer it was an',
#   'start': 20.8,
#   'duration': 4.2},
#  {'text': 'old Macintosh I just fell in love with',
#   'start': 22.72,
#   'duration': 5.16},
#  {'text': 'it at some point if you have high agency',
#   'start': 25.0,
#   'duration': 4.359},
#  {'text': "you will end up where you're meant to go",
#   'start': 27.88,
#   'duration': 2.879},
#  {'text': "it's just going to take some effort did",
#   'start': 29.359,
#   'duration': 3.321},
#  {'text': 'it do anything for your mind I kind of',
#   'start': 30.759,
#   'duration': 3.001},
#  {'text': 'sometimes have these near-death', 'start': 32.68, 'duration': 2.84},
#  {'text': "exercises where it's just like I imagine",
#   'start': 33.76,
#   'duration': 3.04},
#  {'text': "myself dying it's like you can see",
#   'start': 35.52,
#   'duration': 3.28},
#  {'text': 'things fading out they call orgasm the',
#   'start': 36.8,
#   'duration': 3.84},
#  {'text': 'petite more The Little Death right did',
#   'start': 38.8,
#   'duration': 4.52},
#  {'text': 'you ever smoke weed you know I live in',
#   'start': 40.64,
#   'duration': 4.8},
#  {'text': 'California well the common belief now is',
#   'start': 43.32,
#   'duration': 3.64},
#  {'text': 'that like mushrooms are harmless right',
#   'start': 45.44,
#   'duration': 2.88},
#  {'text': "they're", 'start': 46.96, 'duration': 4.279},
#  {'text': "not do you miss your childhood I don't",
#   'start': 48.32,
#   'duration': 5.8},
#  {'text': "have a it's like a dream is it real",
#   'start': 51.239,
#   'duration': 4.0},
#  {'text': 'actually', 'start': 54.12, 'duration': 3.759},
#  {'text': 'happened B has had a great saying in',
#   'start': 55.239,
#   'duration': 4.921},
#  {'text': 'every human there is a sense that',
#   'start': 57.879,
#   'duration': 5.401},
#  {'text': 'something infinite has been lost wow has',
#   'start': 60.16,
#   'duration': 5.56},
#  {'text': 'marriage brought further understanding',
#   'start': 63.28,
#   'duration': 4.0},
#  {'text': "when it comes to life there's a secret",
#   'start': 65.72,
#   'duration': 3.28},
#  {'text': 'to a happy relationship is to happy',
#   'start': 67.28,
#   'duration': 4.04},
#  {'text': "people you know what I've learned about",
#   'start': 69.0,
#   'duration': 5.119},
#  {'text': "marriage one's wife is always right and",
#   'start': 71.32,
#   'duration': 4.32},
#  {'text': "that's the rule one should follow yes I",
#   'start': 74.119,
#   'duration': 3.481},
#  {'text': 'reject that completely uh yeah people',
#   'start': 75.64,
#   'duration': 3.839},
#  {'text': "say like happy wife happy life that's",
#   'start': 77.6,
#   'duration': 3.64},
#  {'text': "all propaganda that's all feminine",
#   'start': 79.479,
#   'duration': 4.6},
#  {'text': "propaganda you're being brainwashed no",
#   'start': 81.24,
#   'duration': 5.32},
#  {'text': 'both people have to be equally happy',
#   'start': 84.079,
#   'duration': 5.0},
#  {'text': 'really you know from the outside looking',
#   'start': 86.56,
#   'duration': 5.44},
#  {'text': 'in I personally have this impression of',
#   'start': 89.079,
#   'duration': 5.72},
#  {'text': 'Naval rikan the brand and the human and',
#   'start': 92.0,
#   'duration': 4.68},
#  {'text': "I feel like nothing hurts that guy I'm a",
#   'start': 94.799,
#   'duration': 4.521},
#  {'text': 'very paranoid person so my rule is I',
#   'start': 96.68,
#   'duration': 4.0},
#  {'text': "don't fight with people if somebody",
#   'start': 99.32,
#   'duration': 3.079},
#  {'text': 'wants to fight with me we get one fight',
#   'start': 100.68,
#   'duration': 3.32},
#  {'text': "and then it's over there's a lot of",
#   'start': 102.399,
#   'duration': 3.4},
#  {'text': 'people out there and life is long do you',
#   'start': 104.0,
#   'duration': 4.799},
#  {'text': 'pray if you are older in life and you',
#   'start': 105.799,
#   'duration': 4.96},
#  {'text': "don't have the Next Generation to look",
#   'start': 108.799,
#   'duration': 5.201},
#  {'text': 'forward to then you better find God fast',
#   'start': 110.759,
#   'duration': 5.081},
#  {'text': "because I don't think like your own mind",
#   'start': 114.0,
#   'duration': 3.32},
#  {'text': 'and your own life will be kind to you as',
#   'start': 115.84,
#   'duration': 4.76},
#  {'text': 'you get older', 'start': 117.32, 'duration': 3.28},
#  {'text': 'if you know who Naval ravikant is please',
#   'start': 123.0,
#   'duration': 3.96},
#  {'text': 'head straight into the conversation this',
#   'start': 124.799,
#   'duration': 4.641},
#  {'text': 'intro is primarily crafted for those of',
#   'start': 126.96,
#   'duration': 3.96},
#  {'text': 'you who are being introduced to Naval',
#   'start': 129.44,
#   'duration': 3.84},
#  {'text': 'ravikant for the first time surprisingly',
#   'start': 130.92,
#   'duration': 5.52},
#  {'text': "there's a lot of people in India who are",
#   'start': 133.28,
#   'duration': 5.679},
#  {'text': 'yet to be introduced to who I consider',
#   'start': 136.44,
#   'duration': 4.96},
#  {'text': 'to be the greatest philosopher of our',
#   'start': 138.959,
#   'duration': 4.481},
#  {'text': 'times I genuinely believe that history',
#   'start': 141.4,
#   'duration': 5.4},
#  {'text': 'will remember him as one of the greatest',
#   'start': 143.44,
#   'duration': 6.68},
#  {'text': 'Minds that lived in the 21st century',
#   'start': 146.8,
#   'duration': 6.2},
#  {'text': "he's an extremely humble extremely",
#   'start': 150.12,
#   'duration': 5.6},
#  {'text': 'relaxed individual so I know that this',
#   'start': 153.0,
#   'duration': 4.72},
#  {'text': 'intro is going to bother him on some',
#   'start': 155.72,
#   'duration': 4.519},
#  {'text': "level that's the side of Naval that I",
#   'start': 157.72,
#   'duration': 4.56},
#  {'text': 'got to know through this conversation',
#   'start': 160.239,
#   'duration': 5.121},
#  {'text': 'this is the most casual conversation',
#   'start': 162.28,
#   'duration': 5.16},
#  {'text': 'that the internet has ever seen with',
#   'start': 165.36,
#   'duration': 4.64},
#  {'text': 'this man it was one of the biggest',
#   'start': 167.44,
#   'duration': 4.6},
#  {'text': 'honors of my own podcasting career to be',
#   'start': 170.0,
#   'duration': 4.08},
#  {'text': 'sharing screen space and podcasting',
#   'start': 172.04,
#   'duration': 4.479},
#  {'text': 'space with Naval ravikant if I had to',
#   'start': 174.08,
#   'duration': 3.799},
#  {'text': 'introduce him professionally of course',
#   'start': 176.519,
#   'duration': 2.961},
#  {'text': "I'd tell you how he's one of the most",
#   'start': 177.879,
#   'duration': 3.921},
#  {'text': 'iconic Angel Investors in the world of',
#   'start': 179.48,
#   'duration': 4.72},
#  {'text': "course i' tell you about how he's one of",
#   'start': 181.8,
#   'duration': 4.76},
#  {'text': 'the most important thought leaders for',
#   'start': 184.2,
#   'duration': 5.399},
#  {'text': 'Silicon Valley and the world of Global',
#   'start': 186.56,
#   'duration': 6.239},
#  {'text': "Twitter or X it's Naval ravikant on the",
#   'start': 189.599,
#   'duration': 5.041},
#  {'text': 'RV show this is one of the most',
#   'start': 192.799,
#   'duration': 3.601},
#  {'text': 'memorable episodes for me on a personal',
#   'start': 194.64,
#   'duration': 4.44},
#  {'text': "level but if you're looking for depth in",
#   'start': 196.4,
#   'duration': 4.839},
#  {'text': "conversation it doesn't get deeper than",
#   'start': 199.08,
#   'duration': 5.799},
#  {'text': "Naval rikan's mind it's Naval on",
#   'start': 201.239,
#   'duration': 7.321},
#  {'text': 'TRS huge day for my career honestly huge',
#   'start': 204.879,
#   'duration': 5.401},
#  {'text': 'day for my own Human Experience',
#   'start': 208.56,
#   'duration': 3.83},
#  {'text': 'enjoy the', 'start': 210.28, 'duration': 16.68},
#  {'text': '[Music]', 'start': 212.39, 'duration': 14.57},
#  {'text': 'episode this is one of the biggest days',
#   'start': 227.519,
#   'duration': 4.481},
#  {'text': "of my podcasting career but I'm also",
#   'start': 230.0,
#   'duration': 4.079},
#  {'text': "feeling supremely comfortable that's the",
#   'start': 232.0,
#   'duration': 4.04},
#  {'text': "magic of Nel ravian oh you're very nice",
#   'start': 234.079,
#   'duration': 3.761},
#  {'text': 'welcome to the ren show sir thank you',
#   'start': 236.04,
#   'duration': 4.0},
#  {'text': 'thanks for having me uh visualize this',
#   'start': 237.84,
#   'duration': 4.2},
#  {'text': 'moment so much over the years so as I',
#   'start': 240.04,
#   'duration': 4.68},
#  {'text': 'told you in the car ride on the way here',
#   'start': 242.04,
#   'duration': 5.0},
#  {'text': "uh I'm full of gratitude and as we go",
#   'start': 244.72,
#   'duration': 3.76},
#  {'text': "forward in this conversation I'm going",
#   'start': 247.04,
#   'duration': 3.479},
#  {'text': 'to pour more and more gratitude on you',
#   'start': 248.48,
#   'duration': 3.52},
#  {'text': 'uh when we were on our way here from the',
#   'start': 250.519,
#   'duration': 3.241},
#  {'text': 'network state conference I saw how much',
#   'start': 252.0,
#   'duration': 4.239},
#  {'text': 'you were hounded uh people just want to',
#   'start': 253.76,
#   'duration': 4.879},
#  {'text': 'come up and say that they love you uh',
#   'start': 256.239,
#   'duration': 4.161},
#  {'text': 'this takes me back to that Joe Rogan',
#   'start': 258.639,
#   'duration': 4.56},
#  {'text': 'episode you did in 2019 are you aware of',
#   'start': 260.4,
#   'duration': 6.239},
#  {'text': "how many young men's lives that episode",
#   'start': 263.199,
#   'duration': 6.641},
#  {'text': 'affected I have no idea why to be honest',
#   'start': 266.639,
#   'duration': 5.12},
#  {'text': 'I feel like I just said the same things',
#   'start': 269.84,
#   'duration': 4.199},
#  {'text': "I was saying they're kind of obvious and",
#   'start': 271.759,
#   'duration': 5.601},
#  {'text': "maybe uh don't be so easily influenced",
#   'start': 274.039,
#   'duration': 5.641},
#  {'text': 'really yeah think for yourself you know',
#   'start': 277.36,
#   'duration': 3.88},
#  {'text': 'decide for yourself you know how I look',
#   'start': 279.68,
#   'duration': 4.68},
#  {'text': 'at it so in 2019 I was 26 running four',
#   'start': 281.24,
#   'duration': 5.0},
#  {'text': 'businesses parall getting extremely',
#   'start': 284.36,
#   'duration': 4.119},
#  {'text': 'stressed out but those two hours of that',
#   'start': 286.24,
#   'duration': 4.6},
#  {'text': 'episode created switches in me and my',
#   'start': 288.479,
#   'duration': 6.0},
#  {'text': 'journey from age 26 to age 31 has been',
#   'start': 290.84,
#   'duration': 5.68},
#  {'text': 'much more lubricated especially from a',
#   'start': 294.479,
#   'duration': 3.881},
#  {'text': "mental health perspective so you've done",
#   'start': 296.52,
#   'duration': 3.84},
#  {'text': 'a lot for the mental health of many men',
#   'start': 298.36,
#   'duration': 4.08},
#  {'text': 'all over the world how how much do we',
#   'start': 300.36,
#   'duration': 3.52},
#  {'text': 'really figure out ourselves right',
#   'start': 302.44,
#   'duration': 3.92},
#  {'text': "there's like there there's what are the",
#   'start': 303.88,
#   'duration': 3.64},
#  {'text': 'different kinds of knowledge this weth',
#   'start': 306.36,
#   'duration': 2.6},
#  {'text': "thinking through right I'm just thinking",
#   'start': 307.52,
#   'duration': 3.44},
#  {'text': "it through with you so there's Knowledge",
#   'start': 308.96,
#   'duration': 4.0},
#  {'text': 'from direct experience right you',
#   'start': 310.96,
#   'duration': 4.04},
#  {'text': 'experience something and that generates',
#   'start': 312.96,
#   'duration': 4.2},
#  {'text': "knowledge inside of you there's", 'start': 315.0, 'duration': 4.12},
#  {'text': 'knowledge that you pick up from other',
#   'start': 317.16,
#   'duration': 3.96},
#  {'text': "sources you just a vessel that's passing",
#   'start': 319.12,
#   'duration': 3.32},
#  {'text': 'through you you picked it up you',
#   'start': 321.12,
#   'duration': 2.799},
#  {'text': 'synthesize it you', 'start': 322.44, 'duration': 4.879},
#  {'text': "regurgitate there's uh knowledge that",
#   'start': 323.919,
#   'duration': 7.041},
#  {'text': "you create which is rare um um I don't",
#   'start': 327.319,
#   'duration': 6.121},
#  {'text': 'know if I said anything original really',
#   'start': 330.96,
#   'duration': 4.64},
#  {'text': "yeah I don't know I don't know but I",
#   'start': 333.44,
#   'duration': 3.759},
#  {'text': 'think you accumulated a lot of data',
#   'start': 335.6,
#   'duration': 4.2},
#  {'text': 'which is back by years of reading and',
#   'start': 337.199,
#   'duration': 5.881},
#  {'text': 'research I think if I were to look back',
#   'start': 339.8,
#   'duration': 6.0},
#  {'text': 'I would say that the only true knowledge',
#   'start': 343.08,
#   'duration': 7.0},
#  {'text': 'I have is the knowledge that is uh',
#   'start': 345.8,
#   'duration': 8.399},
#  {'text': 'directly verified by me and uh fits in',
#   'start': 350.08,
#   'duration': 7.399},
#  {'text': 'with the other pieces so I view myself',
#   'start': 354.199,
#   'duration': 6.28},
#  {'text': 'as a very basic thinker really yeah I',
#   'start': 357.479,
#   'duration': 4.56},
#  {'text': "don't view myself as an advanced thinker",
#   'start': 360.479,
#   'duration': 3.961},
#  {'text': "I'm not an expert in anything but what I",
#   'start': 362.039,
#   'duration': 4.44},
#  {'text': 'like to do is everything that comes my',
#   'start': 364.44,
#   'duration': 4.44},
#  {'text': 'way I like to deeply understand it as',
#   'start': 366.479,
#   'duration': 4.28},
#  {'text': 'simply as possible I have to be able to',
#   'start': 368.88,
#   'duration': 3.96},
#  {'text': 'put it in simple words and simple',
#   'start': 370.759,
#   'duration': 4.641},
#  {'text': 'Frameworks and simple Concepts and I',
#   'start': 372.84,
#   'duration': 5.359},
#  {'text': 'have to be able to do it uh almost',
#   'start': 375.4,
#   'duration': 5.84},
#  {'text': 'visually in my mind and exponentially',
#   'start': 378.199,
#   'duration': 4.681},
#  {'text': 'have to map it to some experience that I',
#   'start': 381.24,
#   'duration': 3.519},
#  {'text': 'have and then I have to be able to take',
#   'start': 382.88,
#   'duration': 3.2},
#  {'text': 'that and I have to be able to plug it',
#   'start': 384.759,
#   'duration': 2.921},
#  {'text': 'into something else I understand it has',
#   'start': 386.08,
#   'duration': 4.44},
#  {'text': 'to fit in a steel frame of understanding',
#   'start': 387.68,
#   'duration': 5.32},
#  {'text': 'at the basics of knowledge uh so for',
#   'start': 390.52,
#   'duration': 4.04},
#  {'text': 'example mathematics I was never very',
#   'start': 393.0,
#   'duration': 3.0},
#  {'text': 'good at mathematics I wanted to be a',
#   'start': 394.56,
#   'duration': 2.84},
#  {'text': "physicist but I I wasn't good at",
#   'start': 396.0,
#   'duration': 3.84},
#  {'text': 'calculus but my basic math is really',
#   'start': 397.4,
#   'duration': 4.6},
#  {'text': "really good um the same way I don't have",
#   'start': 399.84,
#   'duration': 4.479},
#  {'text': 'the largest vocabulary but I have a very',
#   'start': 402.0,
#   'duration': 4.36},
#  {'text': 'solid vocabulary and I can be very',
#   'start': 404.319,
#   'duration': 4.481},
#  {'text': 'precise with my words even when I speak',
#   'start': 406.36,
#   'duration': 3.88},
#  {'text': "I'm not the fastest speaker I'm not the",
#   'start': 408.8,
#   'duration': 4.32},
#  {'text': "slowest speaker so I think for me it's",
#   'start': 410.24,
#   'duration': 5.679},
#  {'text': "just about I don't take there's a great",
#   'start': 413.12,
#   'duration': 5.759},
#  {'text': 'uh motto from the Royal Society which',
#   'start': 415.919,
#   'duration': 5.201},
#  {'text': 'was the Society of scientists in uh',
#   'start': 418.879,
#   'duration': 4.561},
#  {'text': 'Britain during their Enlightenment era',
#   'start': 421.12,
#   'duration': 4.639},
#  {'text': 'and uh the motto of the royal so Society',
#   'start': 423.44,
#   'duration': 4.12},
#  {'text': "is nullus and verba I'm sorry if I'm",
#   'start': 425.759,
#   'duration': 4.16},
#  {'text': 'mangling the Latin but it means take no',
#   'start': 427.56,
#   'duration': 5.28},
#  {'text': "one's word for it and I love that uh",
#   'start': 429.919,
#   'duration': 6.441},
#  {'text': "take no one's word for it so I think uh",
#   'start': 432.84,
#   'duration': 6.16},
#  {'text': 'we are encouraged these days to take in',
#   'start': 436.36,
#   'duration': 4.279},
#  {'text': 'knowledge pour it into our heads like a',
#   'start': 439.0,
#   'duration': 5.039},
#  {'text': 'bucket and uh we regurgitate it and we',
#   'start': 440.639,
#   'duration': 5.0},
#  {'text': 'use fancy words to cover up what we',
#   'start': 444.039,
#   'duration': 4.521},
#  {'text': "don't mean what we don't know and I",
#   'start': 445.639,
#   'duration': 5.24},
#  {'text': "don't accept that unless I understand",
#   'start': 448.56,
#   'duration': 4.639},
#  {'text': 'something at its core fundamental level',
#   'start': 450.879,
#   'duration': 3.801},
#  {'text': "I don't understand it and then beyond",
#   'start': 453.199,
#   'duration': 3.201},
#  {'text': "that level I get bored I don't care to",
#   'start': 454.68,
#   'duration': 4.76},
#  {'text': 'understand it so I think just being able',
#   'start': 456.4,
#   'duration': 6.16},
#  {'text': 'to be very particular about what you',
#   'start': 459.44,
#   'duration': 5.96},
#  {'text': 'take in make sure you truly understand',
#   'start': 462.56,
#   'duration': 5.319},
#  {'text': 'it and that it is true truth is the most',
#   'start': 465.4,
#   'duration': 4.56},
#  {'text': "important thing because if you're going",
#   'start': 467.879,
#   'duration': 3.16},
#  {'text': "ahead with falsehoods because they're",
#   'start': 469.96,
#   'duration': 2.16},
#  {'text': "convenient you're just going to walk",
#   'start': 471.039,
#   'duration': 2.84},
#  {'text': 'around bumping your head against reality',
#   'start': 472.12,
#   'duration': 3.759},
#  {'text': "and wondering why it hurts so it's",
#   'start': 473.879,
#   'duration': 4.04},
#  {'text': 'important to just always look for the',
#   'start': 475.879,
#   'duration': 4.32},
#  {'text': 'truth figure it out for yourself make',
#   'start': 477.919,
#   'duration': 4.56},
#  {'text': 'sure it fits into your understanding be',
#   'start': 480.199,
#   'duration': 3.761},
#  {'text': "open to revising it because you're",
#   'start': 482.479,
#   'duration': 3.12},
#  {'text': "always wrong it's just question of how",
#   'start': 483.96,
#   'duration': 5.04},
#  {'text': 'wrong you are uh and then using that to',
#   'start': 485.599,
#   'duration': 5.201},
#  {'text': 'uh find the commonalities in life and',
#   'start': 489.0,
#   'duration': 4.96},
#  {'text': "and navigate it and I think that's why",
#   'start': 490.8,
#   'duration': 6.6},
#  {'text': "uh you're better off asking someone like",
#   'start': 493.96,
#   'duration': 6.959},
#  {'text': 'me about very basic things uh than about',
#   'start': 497.4,
#   'duration': 5.84},
#  {'text': 'very Advanced things can I ask you a',
#   'start': 500.919,
#   'duration': 4.081},
#  {'text': "basic question sure yeah please what's",
#   'start': 503.24,
#   'duration': 2.84},
#  {'text': 'the meaning of', 'start': 505.0, 'duration': 3.319},
#  {'text': 'life we talk about this for hours I',
#   'start': 506.08,
#   'duration': 3.679},
#  {'text': 'think about it all the time I think',
#   'start': 508.319,
#   'duration': 4.121},
#  {'text': 'about it I I want to kind of reframe it',
#   'start': 509.759,
#   'duration': 5.16},
#  {'text': "a little bit sure yeah uh what's new",
#   'start': 512.44,
#   'duration': 4.839},
#  {'text': "right now in life for you it's been 5",
#   'start': 514.919,
#   'duration': 3.961},
#  {'text': 'years since that Joe Rogan episode and',
#   'start': 517.279,
#   'duration': 3.521},
#  {'text': 'we got to know you so deeply then yeah',
#   'start': 518.88,
#   'duration': 3.24},
#  {'text': "but what's happened in the last five",
#   'start': 520.8,
#   'duration': 2.919},
#  {'text': "years I don't I don't I don't uh",
#   'start': 522.12,
#   'duration': 3.56},
#  {'text': "retrospect on myself I don't think about",
#   'start': 523.719,
#   'duration': 4.641},
#  {'text': "myself that's what's new no no I just",
#   'start': 525.68,
#   'duration': 4.04},
#  {'text': "don't I I couldn't tell you because I",
#   'start': 528.36,
#   'duration': 2.68},
#  {'text': "don't think about myself I don't think",
#   'start': 529.72,
#   'duration': 2.84},
#  {'text': "about what's changed in my life and if",
#   'start': 531.04,
#   'duration': 3.08},
#  {'text': 'my life is good or bad or if this',
#   'start': 532.56,
#   'duration': 3.32},
#  {'text': "happened or that happened and I don't",
#   'start': 534.12,
#   'duration': 3.64},
#  {'text': "look at all photos of me and I don't",
#   'start': 535.88,
#   'duration': 3.84},
#  {'text': 'think about old trips and I think about',
#   'start': 537.76,
#   'duration': 3.639},
#  {'text': "people that are gone you know I don't I",
#   'start': 539.72,
#   'duration': 2.92},
#  {'text': "don't think about the past I just don't",
#   'start': 541.399,
#   'duration': 5.12},
#  {'text': 'live in the past at all do you pray uh',
#   'start': 542.64,
#   'duration': 6.08},
#  {'text': 'not in the traditional sense no uh I',
#   'start': 546.519,
#   'duration': 4.121},
#  {'text': 'think prayer implies some kind of an',
#   'start': 548.72,
#   'duration': 3.6},
#  {'text': "external entity that I'm asking", 'start': 550.64, 'duration': 3.8},
#  {'text': 'something for and sure like every person',
#   'start': 552.32,
#   'duration': 4.36},
#  {'text': 'I might have done that here or there um',
#   'start': 554.44,
#   'duration': 3.88},
#  {'text': "usually we're fair weather friends with",
#   'start': 556.68,
#   'duration': 3.0},
#  {'text': "any God that's out there right when we",
#   'start': 558.32,
#   'duration': 2.959},
#  {'text': "need help we're like all prayer and when",
#   'start': 559.68,
#   'duration': 2.88},
#  {'text': "we don't we're like everything's good",
#   'start': 561.279,
#   'duration': 3.601},
#  {'text': "it's all me right so no I don't I don't",
#   'start': 562.56,
#   'duration': 4.64},
#  {'text': 'pray in the traditional sense', 'start': 564.88, 'duration': 6.04},
#  {'text': 'uh but I am very deeply I hate the word',
#   'start': 567.2,
#   'duration': 5.6},
#  {'text': "but it's spiritual right and I would",
#   'start': 570.92,
#   'duration': 3.359},
#  {'text': 'Define spiritual in a negative way it',
#   'start': 572.8,
#   'duration': 3.92},
#  {'text': 'just means not mental not physical right',
#   'start': 574.279,
#   'duration': 4.161},
#  {'text': 'so but why do you hate the', 'start': 576.72, 'duration': 4.0},
#  {'text': "words because it's overloaded with a lot",
#   'start': 578.44,
#   'duration': 4.76},
#  {'text': "of religiosity um all of a sudden you're",
#   'start': 580.72,
#   'duration': 3.96},
#  {'text': "supposed to be a spiritual being you're",
#   'start': 583.2,
#   'duration': 2.8},
#  {'text': "supposed to do yoga you're supposed to",
#   'start': 584.68,
#   'duration': 2.36},
#  {'text': "meditate and you're supposed to sit",
#   'start': 586.0,
#   'duration': 2.92},
#  {'text': "cross- lugged and you're supposed to you",
#   'start': 587.04,
#   'duration': 3.56},
#  {'text': 'know then you argue about is the bagat',
#   'start': 588.92,
#   'duration': 4.88},
#  {'text': 'Gita or the asash Gita or the you know',
#   'start': 590.6,
#   'duration': 4.679},
#  {'text': 'all of these roads lead to the same',
#   'start': 593.8,
#   'duration': 5.68},
#  {'text': 'place um the the the best way I would SU',
#   'start': 595.279,
#   'duration': 6.481},
#  {'text': 'Ariz my thinking on this is that I think',
#   'start': 599.48,
#   'duration': 5.0},
#  {'text': 'existence itself is a miracle the oldest',
#   'start': 601.76,
#   'duration': 4.519},
#  {'text': 'questions are why is there something',
#   'start': 604.48,
#   'duration': 3.32},
#  {'text': 'instead of nothing why are we here',
#   'start': 606.279,
#   'duration': 2.68},
#  {'text': "what's the meaning of life these are all",
#   'start': 607.8,
#   'duration': 4.719},
#  {'text': 'just variants in the same question and',
#   'start': 608.959,
#   'duration': 5.361},
#  {'text': 'there is no answer to that does that',
#   'start': 612.519,
#   'duration': 3.201},
#  {'text': 'mean there can never be an answer to',
#   'start': 614.32,
#   'duration': 3.639},
#  {'text': 'that no not necessarily but if you start',
#   'start': 615.72,
#   'duration': 3.52},
#  {'text': "going down that road you'll find all",
#   'start': 617.959,
#   'duration': 3.361},
#  {'text': 'kinds of contradictions for example with',
#   'start': 619.24,
#   'duration': 3.64},
#  {'text': 'just the meaning of life right if there',
#   'start': 621.32,
#   'duration': 3.079},
#  {'text': 'was a single meaning of life then we',
#   'start': 622.88,
#   'duration': 3.28},
#  {'text': 'would all be slaves to it suppose the',
#   'start': 624.399,
#   'duration': 2.961},
#  {'text': 'meaning of life was to help others and',
#   'start': 626.16,
#   'duration': 2.119},
#  {'text': 'we would all be running around trying to',
#   'start': 627.36,
#   'duration': 2.52},
#  {'text': "help others and you know there'd be no",
#   'start': 628.279,
#   'duration': 3.521},
#  {'text': 'room for the individual if the meaning',
#   'start': 629.88,
#   'duration': 4.079},
#  {'text': 'of life was to you know be strong and',
#   'start': 631.8,
#   'duration': 3.8},
#  {'text': "fit and healthy then we'd all be working",
#   'start': 633.959,
#   'duration': 4.401},
#  {'text': "out um we'd all be I don't know how beer",
#   'start': 635.6,
#   'duration': 4.32},
#  {'text': "and biceps go together but you know we'd",
#   'start': 638.36,
#   'duration': 4.719},
#  {'text': "all be building our biceps so it's",
#   'start': 639.92,
#   'duration': 4.919},
#  {'text': 'better that there is no overarching',
#   'start': 643.079,
#   'duration': 3.281},
#  {'text': "singular meaning of life it's better",
#   'start': 644.839,
#   'duration': 3.481},
#  {'text': 'that there are personal interpretations',
#   'start': 646.36,
#   'duration': 3.68},
#  {'text': 'got um however within those personal',
#   'start': 648.32,
#   'duration': 5.0},
#  {'text': 'interpretations you know we we all have',
#   'start': 650.04,
#   'duration': 4.799},
#  {'text': 'even though we have complete freedom to',
#   'start': 653.32,
#   'duration': 3.0},
#  {'text': 'choose any meaning that we want and we',
#   'start': 654.839,
#   'duration': 4.161},
#  {'text': 'can create our own meaning at any moment',
#   'start': 656.32,
#   'duration': 4.199},
#  {'text': 'um', 'start': 659.0, 'duration': 2.959},
#  {'text': 'there are certain common things in what',
#   'start': 660.519,
#   'duration': 3.401},
#  {'text': "we all want as well and so that's kind",
#   'start': 661.959,
#   'duration': 4.281},
#  {'text': 'of the Paradox of being a human',
#   'start': 663.92,
#   'duration': 3.919},
#  {'text': "individual where you're completely an",
#   'start': 666.24,
#   'duration': 3.279},
#  {'text': "individual but you're also completely",
#   'start': 667.839,
#   'duration': 3.56},
#  {'text': 'Interlink to everything and anything',
#   'start': 669.519,
#   'duration': 4.281},
#  {'text': "that exists you couldn't change you",
#   'start': 671.399,
#   'duration': 3.641},
#  {'text': "couldn't change a particle in the",
#   'start': 673.8,
#   'duration': 3.56},
#  {'text': 'universe without changing this moment',
#   'start': 675.04,
#   'duration': 5.32},
#  {'text': 'right not in any meaningful way um',
#   'start': 677.36,
#   'duration': 4.68},
#  {'text': "although that's not entirely true there",
#   'start': 680.36,
#   'duration': 3.2},
#  {'text': 'are error correcting mechanisms built',
#   'start': 682.04,
#   'duration': 3.68},
#  {'text': 'into into the structure of the universe',
#   'start': 683.56,
#   'duration': 6.279},
#  {'text': 'so uh but a lot of things had to cons in',
#   'start': 685.72,
#   'duration': 6.04},
#  {'text': 'a very particular way to bring us here',
#   'start': 689.839,
#   'duration': 5.56},
#  {'text': 'together today right um so in that sense',
#   'start': 691.76,
#   'duration': 5.44},
#  {'text': 'everything is very interconnected on the',
#   'start': 695.399,
#   'duration': 2.641},
#  {'text': 'other', 'start': 697.2, 'duration': 3.16},
#  {'text': 'hand my life is and your lives are',
#   'start': 698.04,
#   'duration': 4.12},
#  {'text': 'single player games inside our heads you',
#   'start': 700.36,
#   'duration': 3.68},
#  {'text': 'know we interpret everything from birth',
#   'start': 702.16,
#   'duration': 5.119},
#  {'text': 'to death uh your experience of uh your',
#   'start': 704.04,
#   'duration': 5.84},
#  {'text': 'experiences are singular to you uh no',
#   'start': 707.279,
#   'duration': 4.521},
#  {'text': 'one will truly ever understand you or',
#   'start': 709.88,
#   'duration': 4.12},
#  {'text': "get you uh and you're always searching",
#   'start': 711.8,
#   'duration': 4.96},
#  {'text': 'for that Unity that connection that that',
#   'start': 714.0,
#   'duration': 6.2},
#  {'text': 'going back to uh you know Oneness Source',
#   'start': 716.76,
#   'duration': 4.68},
#  {'text': 'togetherness whatever you want to call',
#   'start': 720.2,
#   'duration': 3.6},
#  {'text': "it Community there's many words for",
#   'start': 721.44,
#   'duration': 4.88},
#  {'text': 'it in terms of uh you know back to',
#   'start': 723.8,
#   'duration': 4.2},
#  {'text': 'meaning of life the way I think of it is',
#   'start': 726.32,
#   'duration': 4.199},
#  {'text': 'that existence itself is a miracle and',
#   'start': 728.0,
#   'duration': 4.839},
#  {'text': 'everything else is science and I think',
#   'start': 730.519,
#   'duration': 3.961},
#  {'text': "that's the best of all possible worlds",
#   'start': 732.839,
#   'duration': 4.24},
#  {'text': 'so spirituality is a side that lies on',
#   'start': 734.48,
#   'duration': 5.52},
#  {'text': 'what who am I why am I here how long',
#   'start': 737.079,
#   'duration': 5.2},
#  {'text': 'have I got what am I here for and these',
#   'start': 740.0,
#   'duration': 4.519},
#  {'text': 'are questions that are really only',
#   'start': 742.279,
#   'duration': 4.521},
#  {'text': 'answerable at a personal level this',
#   'start': 744.519,
#   'duration': 4.68},
#  {'text': "miraculous little world that we're in is",
#   'start': 746.8,
#   'duration': 4.76},
#  {'text': "beautifully put together I couldn't I",
#   'start': 749.199,
#   'duration': 3.961},
#  {'text': "couldn't do a better job for sure for",
#   'start': 751.56,
#   'duration': 4.04},
#  {'text': "sure I couldn't even begin to do the job",
#   'start': 753.16,
#   'duration': 4.72},
#  {'text': 'and just to give you some ideas as to',
#   'start': 755.6,
#   'duration': 3.799},
#  {'text': 'you know just some observations how well',
#   'start': 757.88,
#   'duration': 4.079},
#  {'text': "it's put together the fact that science",
#   'start': 759.399,
#   'duration': 5.12},
#  {'text': "works that's magic technology works that",
#   'start': 761.959,
#   'duration': 4.481},
#  {'text': 'is Magic you go back and you read books',
#   'start': 764.519,
#   'duration': 4.12},
#  {'text': 'on magic or magicians or fantasy books',
#   'start': 766.44,
#   'duration': 3.519},
#  {'text': "they don't have a hundred of the power",
#   'start': 768.639,
#   'duration': 2.161},
#  {'text': "that we have they don't have", 'start': 769.959, 'duration': 2.041},
#  {'text': "self-driving cars they don't have",
#   'start': 770.8,
#   'duration': 3.0},
#  {'text': "smartphones they don't have antibiotics",
#   'start': 772.0,
#   'duration': 3.6},
#  {'text': "they don't have Rockets um they don't",
#   'start': 773.8,
#   'duration': 3.96},
#  {'text': "even have fantasy novels they don't even",
#   'start': 775.6,
#   'duration': 3.96},
#  {'text': "have clean running water they don't have",
#   'start': 777.76,
#   'duration': 3.519},
#  {'text': "reliable food they don't have food",
#   'start': 779.56,
#   'duration': 4.76},
#  {'text': 'delivery services right uh so we are',
#   'start': 781.279,
#   'duration': 5.12},
#  {'text': 'already living in an age of Miracles',
#   'start': 784.32,
#   'duration': 4.319},
#  {'text': 'that the best part is we can control and',
#   'start': 786.399,
#   'duration': 4.041},
#  {'text': 'the magic spells that we cast are under',
#   'start': 788.639,
#   'duration': 4.041},
#  {'text': 'the opice of science the Wizardry that',
#   'start': 790.44,
#   'duration': 4.72},
#  {'text': 'we create is through technology and',
#   'start': 792.68,
#   'duration': 4.88},
#  {'text': "that's all manipulable through laws and",
#   'start': 795.16,
#   'duration': 4.52},
#  {'text': 'and rules and systems that we discover',
#   'start': 797.56,
#   'duration': 4.56},
#  {'text': 'and we discover and we create and that',
#   'start': 799.68,
#   'duration': 4.599},
#  {'text': "is incredible we're all magicians I",
#   'start': 802.12,
#   'duration': 3.56},
#  {'text': "wouldn't I couldn't ask for a better",
#   'start': 804.279,
#   'duration': 4.041},
#  {'text': 'system if an actual Miracle showed up',
#   'start': 805.68,
#   'duration': 4.599},
#  {'text': 'afterwards supposed somebody showed up',
#   'start': 808.32,
#   'duration': 5.24},
#  {'text': 'and turned uh loaves into fish or water',
#   'start': 810.279,
#   'duration': 5.24},
#  {'text': 'into wine that would destroy our world',
#   'start': 813.56,
#   'duration': 3.0},
#  {'text': 'because all of a sudden you be like oh',
#   'start': 815.519,
#   'duration': 2.521},
#  {'text': "my God there's all these rules for this",
#   'start': 816.56,
#   'duration': 3.24},
#  {'text': "new thing that we don't understand how",
#   'start': 818.04,
#   'duration': 3.359},
#  {'text': 'it works so now science is junk and you',
#   'start': 819.8,
#   'duration': 2.8},
#  {'text': "wouldn't know how to navigate the world",
#   'start': 821.399,
#   'duration': 2.68},
#  {'text': "and now You' be the mercy of demons and",
#   'start': 822.6,
#   'duration': 2.919},
#  {'text': "angels and spirits and you'd be running",
#   'start': 824.079,
#   'duration': 2.88},
#  {'text': 'around worshiping and praying then you',
#   'start': 825.519,
#   'duration': 2.961},
#  {'text': "would pray because you'd be like how do",
#   'start': 826.959,
#   'duration': 3.161},
#  {'text': 'I make sense of this world so I think we',
#   'start': 828.48,
#   'duration': 3.52},
#  {'text': 'live in the best of all possible worlds',
#   'start': 830.12,
#   'duration': 4.12},
#  {'text': 'okay uh I think the geography that one',
#   'start': 832.0,
#   'duration': 5.24},
#  {'text': 'grows up in definitely determines their',
#   'start': 834.24,
#   'duration': 5.519},
#  {'text': 'mindset in life to a large degree',
#   'start': 837.24,
#   'duration': 4.599},
#  {'text': 'and uh personally my take on', 'start': 839.759, 'duration': 5.241},
#  {'text': 'spirituality is affected by growing up',
#   'start': 841.839,
#   'duration': 5.161},
#  {'text': 'in India you read books like the',
#   'start': 845.0,
#   'duration': 4.44},
#  {'text': 'autobiography of your Yogi you read the',
#   'start': 847.0,
#   'duration': 5.079},
#  {'text': 'life of the Buddha uh I definitely feel',
#   'start': 849.44,
#   'duration': 4.0},
#  {'text': "that there's a higher stage of",
#   'start': 852.079,
#   'duration': 2.68},
#  {'text': "Consciousness and I don't feel like",
#   'start': 853.44,
#   'duration': 3.839},
#  {'text': "we've reach the final state of evolution",
#   'start': 854.759,
#   'duration': 4.241},
#  {'text': 'uh there is definitely an end point',
#   'start': 857.279,
#   'duration': 3.641},
#  {'text': 'which is also beyond the next stage of',
#   'start': 859.0,
#   'duration': 4.16},
#  {'text': 'evolution uh and I do believe that you',
#   'start': 860.92,
#   'duration': 3.919},
#  {'text': 'know you say that Cal a calm mind is',
#   'start': 863.16,
#   'duration': 4.0},
#  {'text': "earned MH I think that's one of the",
#   'start': 864.839,
#   'duration': 3.521},
#  {'text': "steps on the ladder and then there's",
#   'start': 867.16,
#   'duration': 2.52},
#  {'text': 'like higher stage', 'start': 868.36, 'duration': 4.36},
#  {'text': "mhm I I don't know how useful it is to",
#   'start': 869.68,
#   'duration': 5.24},
#  {'text': 'prognosticate about where humanity is',
#   'start': 872.72,
#   'duration': 4.32},
#  {'text': 'headed unless you get there yourself',
#   'start': 874.92,
#   'duration': 5.24},
#  {'text': "first uh and and you don't have the",
#   'start': 877.04,
#   'duration': 6.08},
#  {'text': 'ability to do anything for anyone unless',
#   'start': 880.16,
#   'duration': 6.119},
#  {'text': 'you embody it yourself uh so so to the',
#   'start': 883.12,
#   'duration': 4.719},
#  {'text': 'extent that you think humanity is headed',
#   'start': 886.279,
#   'duration': 3.48},
#  {'text': 'there I say get there first and then',
#   'start': 887.839,
#   'duration': 4.521},
#  {'text': 'show them the way I definitely think',
#   'start': 889.759,
#   'duration': 5.2},
#  {'text': 'that Nal rant is already on that ladder',
#   'start': 892.36,
#   'duration': 4.039},
#  {'text': 'as compared to other human beings I have',
#   'start': 894.959,
#   'duration': 3.24},
#  {'text': "no idea where I'm on that ladder you",
#   'start': 896.399,
#   'duration': 3.56},
#  {'text': "don't think you're slightly more",
#   'start': 898.199,
#   'duration': 4.041},
#  {'text': 'evolved no I I', 'start': 899.959, 'duration': 6.32},
#  {'text': "don't that's a loaded question", 'start': 902.24, 'duration': 6.76},
#  {'text': "uh first of all I don't think of myself",
#   'start': 906.279,
#   'duration': 4.201},
#  {'text': 'I I just want to be clear on that and',
#   'start': 909.0,
#   'duration': 3.399},
#  {'text': "that's not a rule it's just a habit I've",
#   'start': 910.48,
#   'duration': 4.24},
#  {'text': 'kind of developed because I found that',
#   'start': 912.399,
#   'duration': 3.921},
#  {'text': 'thinking about yourself is a source of',
#   'start': 914.72,
#   'duration': 3.919},
#  {'text': 'all unhappiness and misery really yes',
#   'start': 916.32,
#   'duration': 4.24},
#  {'text': 'self-obsession is the root of all',
#   'start': 918.639,
#   'duration': 4.041},
#  {'text': 'unhappiness what did Buddha do conquer',
#   'start': 920.56,
#   'duration': 4.079},
#  {'text': 'the self what does that mean means that',
#   'start': 922.68,
#   'duration': 3.079},
#  {'text': 'he saw through the illusion of the',
#   'start': 924.639,
#   'duration': 2.76},
#  {'text': 'separate self what does that did Buddha',
#   'start': 925.759,
#   'duration': 3.921},
#  {'text': 'think about himself not for an instant',
#   'start': 927.399,
#   'duration': 3.8},
#  {'text': 'you know anyone that you think of as an',
#   'start': 929.68,
#   'duration': 3.079},
#  {'text': 'enlightened being does not think about',
#   'start': 931.199,
#   'duration': 3.401},
#  {'text': 'themselves for an instant the happiest',
#   'start': 932.759,
#   'duration': 3.241},
#  {'text': 'people in life when people are their',
#   'start': 934.6,
#   'duration': 3.56},
#  {'text': 'best is because uh they love something',
#   'start': 936.0,
#   'duration': 3.6},
#  {'text': 'more than they love themselves they love',
#   'start': 938.16,
#   'duration': 3.0},
#  {'text': 'their children they love God they love',
#   'start': 939.6,
#   'duration': 3.4},
#  {'text': 'their mission what have you and all',
#   'start': 941.16,
#   'duration': 3.4},
#  {'text': 'misery comes from rumination from',
#   'start': 943.0,
#   'duration': 3.199},
#  {'text': 'sitting around being depressed going in',
#   'start': 944.56,
#   'duration': 3.719},
#  {'text': 'circles in your own head about me me me',
#   'start': 946.199,
#   'duration': 6.361},
#  {'text': 'me is a disease and uh you need the a',
#   'start': 948.279,
#   'duration': 7.761},
#  {'text': 'concept of a me to be effective and to',
#   'start': 952.56,
#   'duration': 5.16},
#  {'text': 'keep track of things you have a memory',
#   'start': 956.04,
#   'duration': 3.159},
#  {'text': 'you have certain predictions your',
#   'start': 957.72,
#   'duration': 3.239},
#  {'text': 'personality patterns but the more you',
#   'start': 959.199,
#   'duration': 3.161},
#  {'text': "self- obsessed the less happy you're",
#   'start': 960.959,
#   'duration': 2.8},
#  {'text': "going to be I guarantee you that and I'm",
#   'start': 962.36,
#   'duration': 2.719},
#  {'text': "not doing I'm not saying I don't think",
#   'start': 963.759,
#   'duration': 3.52},
#  {'text': "about myself to be happy I can't even",
#   'start': 965.079,
#   'duration': 3.76},
#  {'text': "tell you why I don't think about myself",
#   'start': 967.279,
#   'duration': 2.641},
#  {'text': 'I think it just comes from having',
#   'start': 968.839,
#   'duration': 2.8},
#  {'text': 'thought through a lot of things and then',
#   'start': 969.92,
#   'duration': 4.2},
#  {'text': 'just I I get interested in topics and',
#   'start': 971.639,
#   'duration': 4.921},
#  {'text': 'Concepts and ideas and understandings',
#   'start': 974.12,
#   'duration': 5.56},
#  {'text': 'and the more that I sort of focus that',
#   'start': 976.56,
#   'duration': 4.6},
#  {'text': 'way the less I just end up thinking',
#   'start': 979.68,
#   'duration': 3.399},
#  {'text': 'about myself so even like you know',
#   'start': 981.16,
#   'duration': 3.479},
#  {'text': "people ask me like oh how's your day",
#   'start': 983.079,
#   'duration': 3.841},
#  {'text': "going I'm like I have no idea I don't",
#   'start': 984.639,
#   'duration': 4.76},
#  {'text': 'think about it really yeah good maybe if',
#   'start': 986.92,
#   'duration': 4.68},
#  {'text': "I'm really tired I'll say okay I'm tired",
#   'start': 989.399,
#   'duration': 3.201},
#  {'text': 'you know if something really bad',
#   'start': 991.6,
#   'duration': 2.479},
#  {'text': "happened like oh it wasn't a great day",
#   'start': 992.6,
#   'duration': 3.159},
#  {'text': "but most of the time I couldn't even",
#   'start': 994.079,
#   'duration': 3.88},
#  {'text': 'tell you my own State of Mind okay cuz',
#   'start': 995.759,
#   'duration': 4.481},
#  {'text': "I'm not interested in it I don't think",
#   'start': 997.959,
#   'duration': 4.761},
#  {'text': "it's interesting it's interesting for us",
#   'start': 1000.24,
#   'duration': 3.92},
#  {'text': "and I'll give you some perspective here",
#   'start': 1002.72,
#   'duration': 3.84},
#  {'text': 'yeah we were one of the first podcasts',
#   'start': 1004.16,
#   'duration': 5.84},
#  {'text': 'in India uh currently the biggest and I',
#   'start': 1006.56,
#   'duration': 5.04},
#  {'text': "feel that's an outcome of constantly",
#   'start': 1010.0,
#   'duration': 3.56},
#  {'text': "tearing apart people's chest getting",
#   'start': 1011.6,
#   'duration': 3.76},
#  {'text': 'into their hearts and getting to know',
#   'start': 1013.56,
#   'duration': 4.0},
#  {'text': "them because in India we're emotional",
#   'start': 1015.36,
#   'duration': 3.959},
#  {'text': 'people and we want to know the emotions',
#   'start': 1017.56,
#   'duration': 3.04},
#  {'text': "of others we want to know what's in",
#   'start': 1019.319,
#   'duration': 2.481},
#  {'text': "other people's mind or it's dumb luck",
#   'start': 1020.6,
#   'duration': 3.599},
#  {'text': "cuz you started early I'm just kidding",
#   'start': 1021.8,
#   'duration': 4.84},
#  {'text': "or or that of course not I'm just joking",
#   'start': 1024.199,
#   'duration': 4.561},
#  {'text': 'with you luck is definitely a part of me',
#   'start': 1026.64,
#   'duration': 4.52},
#  {'text': 'I mean look luck favors are prepared uh',
#   'start': 1028.76,
#   'duration': 5.079},
#  {'text': 'Joe Rogan uh is incredibly successful',
#   'start': 1031.16,
#   'duration': 4.879},
#  {'text': 'because he was doing podcasting before',
#   'start': 1033.839,
#   'duration': 4.24},
#  {'text': 'his podcasting he was the top guy on',
#   'start': 1036.039,
#   'duration': 3.721},
#  {'text': 'Ustream which was just like a streaming',
#   'start': 1038.079,
#   'duration': 3.321},
#  {'text': 'thing on the internet before podcasting',
#   'start': 1039.76,
#   'duration': 4.36},
#  {'text': "came along so uh there's a certain kind",
#   'start': 1041.4,
#   'duration': 4.439},
#  {'text': 'of person that it takes to be',
#   'start': 1044.12,
#   'duration': 3.839},
#  {'text': 'early you make your own luck in that',
#   'start': 1045.839,
#   'duration': 3.801},
#  {'text': 'sense I actually', 'start': 1047.959, 'duration': 3.761},
#  {'text': 'luck is luck is one of those things that',
#   'start': 1049.64,
#   'duration': 3.52},
#  {'text': "you shouldn't believe in even if it's",
#   'start': 1051.72,
#   'duration': 3.6},
#  {'text': 'true because believing it will hurt your',
#   'start': 1053.16,
#   'duration': 4.759},
#  {'text': 'agency just like victim mentality right',
#   'start': 1055.32,
#   'duration': 3.96},
#  {'text': "thinking you're a victim even if it's",
#   'start': 1057.919,
#   'duration': 2.801},
#  {'text': "true don't believe it because it'll just",
#   'start': 1059.28,
#   'duration': 2.84},
#  {'text': 'hurt your agency because you have no',
#   'start': 1060.72,
#   'duration': 2.88},
#  {'text': 'power as a victim you have no power if',
#   'start': 1062.12,
#   'duration': 4.2},
#  {'text': 'things are up to luck uh whatever power',
#   'start': 1063.6,
#   'duration': 4.959},
#  {'text': 'you have in life comes from believing',
#   'start': 1066.32,
#   'duration': 3.76},
#  {'text': 'that you can change things and do things',
#   'start': 1068.559,
#   'duration': 3.36},
#  {'text': "and even if you can't change the outside",
#   'start': 1070.08,
#   'duration': 3.4},
#  {'text': 'you can at least change the inside No',
#   'start': 1071.919,
#   'duration': 5.441},
#  {'text': 'One controls your mind but you um so',
#   'start': 1073.48,
#   'duration': 6.04},
#  {'text': "yeah it's it's not luck I was jok",
#   'start': 1077.36,
#   'duration': 5.04},
#  {'text': 'talking the question I have for you is',
#   'start': 1079.52,
#   'duration': 5.08},
#  {'text': 'while all of us sit in India and view',
#   'start': 1082.4,
#   'duration': 5.6},
#  {'text': 'Naval ravikant ruling the internet in so',
#   'start': 1084.6,
#   'duration': 6.16},
#  {'text': 'many ways uh a lot of Indians feel very',
#   'start': 1088.0,
#   'duration': 6.6},
#  {'text': 'proud okay to see someone from India uh',
#   'start': 1090.76,
#   'duration': 6.56},
#  {'text': 'you know who shares genetics with us uh',
#   'start': 1094.6,
#   'duration': 5.8},
#  {'text': 'kind of kill it on a world stage uh so',
#   'start': 1097.32,
#   'duration': 5.12},
#  {'text': "I've had this thought experiment lately",
#   'start': 1100.4,
#   'duration': 3.279},
#  {'text': "as I've been researching for this",
#   'start': 1102.44,
#   'duration': 3.44},
#  {'text': 'episode I thought to myself that what if',
#   'start': 1103.679,
#   'duration': 4.401},
#  {'text': "Noel's parents didn't leave India and",
#   'start': 1105.88,
#   'duration': 4.12},
#  {'text': "what if he was in Delhi I'm pretty sure",
#   'start': 1108.08,
#   'duration': 4.56},
#  {'text': "you'd still uh take up some form of",
#   'start': 1110.0,
#   'duration': 3.64},
#  {'text': 'Entrepreneurship knowing your', 'start': 1112.64, 'duration': 2.08},
#  {'text': "personality because I think there's some",
#   'start': 1113.64,
#   'duration': 3.6},
#  {'text': "traits that don't change uh but then",
#   'start': 1114.72,
#   'duration': 4.04},
#  {'text': "there's a lot that changes because of",
#   'start': 1117.24,
#   'duration': 4.08},
#  {'text': "geography I I wonder if you've ever",
#   'start': 1118.76,
#   'duration': 4.0},
#  {'text': 'thought of that reality if your parents',
#   'start': 1121.32,
#   'duration': 4.599},
#  {'text': "didn't leave India uh and go to the US",
#   'start': 1122.76,
#   'duration': 4.24},
#  {'text': 'how would your life be different',
#   'start': 1125.919,
#   'duration': 2.561},
#  {'text': "according to you I don't I don't want to",
#   'start': 1127.0,
#   'duration': 3.039},
#  {'text': 'downplay geography at all I actually',
#   'start': 1128.48,
#   'duration': 3.88},
#  {'text': 'think where you live is the single most',
#   'start': 1130.039,
#   'duration': 4.52},
#  {'text': 'important decision you make uh but the',
#   'start': 1132.36,
#   'duration': 4.48},
#  {'text': 'first part of that is making a decision',
#   'start': 1134.559,
#   'duration': 4.841},
#  {'text': 'uh I like to think that even if my',
#   'start': 1136.84,
# ...
#  {'text': 'self- obsessed and therefore their love',
#   'start': 1753.72,
#   'duration': 5.92},
#  {'text': 'that was earlier turned inwards and',
#   'start': 1756.64,
#   'duration': 6.32},
#  {'text': 'became ego love for the self went',
#   'start': 1759.64,
#   'duration': 6.879},
#  {'text': 'outwards and it still flows uh as a very',
#   'start': 1762.96,
#   'duration': 5.68},
#  {'text': "simple example you know here's something",
#   'start': 1766.519,
#   'duration': 5.04},
#  {'text': 'I uh uh is a little embarrassing but',
#   'start': 1768.64,
#   'duration': 4.24},
#  {'text': "I'll be vulnerable you like vulnerable",
#   'start': 1771.559,
#   'duration': 4.12},
#  {'text': 'vulnerability right so I I I I kind of',
#   'start': 1772.88,
#   'duration': 4.0},
#  {'text': 'sometimes have these near-death',
#   'start': 1775.679,
#   'duration': 3.161},
#  {'text': "exercises right where it's just like I",
#   'start': 1776.88,
#   'duration': 4.24},
#  {'text': "imagine myself dying and it's not",
#   'start': 1778.84,
#   'duration': 4.559},
#  {'text': 'something that I do deliberately just',
#   'start': 1781.12,
#   'duration': 5.36},
#  {'text': 'kind of happens the the moments when you',
#   'start': 1783.399,
#   'duration': 4.961},
#  {'text': 'go into bed but before you fall asleep',
#   'start': 1786.48,
#   'duration': 3.24},
#  {'text': 'are really interesting because your mind',
#   'start': 1788.36,
#   'duration': 2.799},
#  {'text': 'goes into a really hazy almost',
#   'start': 1789.72,
#   'duration': 3.959},
#  {'text': 'psychedelic State and and I used to',
#   'start': 1791.159,
#   'duration': 4.36},
#  {'text': 'meditate a lot and somewhere along the',
#   'start': 1793.679,
#   'duration': 3.681},
#  {'text': 'way I just found that state between',
#   'start': 1795.519,
#   'duration': 3.481},
#  {'text': 'sleeping and waking to be really',
#   'start': 1797.36,
#   'duration': 3.439},
#  {'text': 'entertaining and entertaining', 'start': 1799.0, 'duration': 3.32},
#  {'text': "entertaining yeah it's just entertaining",
#   'start': 1800.799,
#   'duration': 4.24},
#  {'text': "so next time you're falling asleep just",
#   'start': 1802.32,
#   'duration': 4.68},
#  {'text': 'make a just just the smallest effort',
#   'start': 1805.039,
#   'duration': 3.0},
#  {'text': 'because if you make any real effort',
#   'start': 1807.0,
#   'duration': 2.519},
#  {'text': "you'll fall you won't be able to sleep",
#   'start': 1808.039,
#   'duration': 3.201},
#  {'text': 'but make the smallest effort just to be',
#   'start': 1809.519,
#   'duration': 3.321},
#  {'text': "aware of your thoughts as you're falling",
#   'start': 1811.24,
#   'duration': 3.919},
#  {'text': "asleep as you're going to sleep and your",
#   'start': 1812.84,
#   'duration': 3.839},
#  {'text': 'thoughts start going wackier and wackier',
#   'start': 1815.159,
#   'duration': 3.12},
#  {'text': 'and wackier and they will just get wild',
#   'start': 1816.679,
#   'duration': 4.12},
#  {'text': "like I'll have cats talking to me and",
#   'start': 1818.279,
#   'duration': 4.441},
#  {'text': 'you know just like weird stuff going in',
#   'start': 1820.799,
#   'duration': 3.321},
#  {'text': "and out just it's like dreams you're",
#   'start': 1822.72,
#   'duration': 3.079},
#  {'text': "you're basically lucid dreaming as",
#   'start': 1824.12,
#   'duration': 3.08},
#  {'text': "you're falling asleep and they're the",
#   'start': 1825.799,
#   'duration': 3.36},
#  {'text': "craziest dream they don't make any sense",
#   'start': 1827.2,
#   'duration': 3.76},
#  {'text': "it's all nonsense You observe your own",
#   'start': 1829.159,
#   'duration': 3.36},
#  {'text': "thoughts as you're about to fall asleep",
#   'start': 1830.96,
#   'duration': 2.92},
#  {'text': "as I'm about to fall asleep that's when",
#   'start': 1832.519,
#   'duration': 2.28},
#  {'text': "that's when your thoughts start going",
#   'start': 1833.88,
#   'duration': 2.639},
#  {'text': 'off the rails you stop thinking about',
#   'start': 1834.799,
#   'duration': 3.48},
#  {'text': 'like what am I doing tomorrow and how to',
#   'start': 1836.519,
#   'duration': 3.681},
#  {'text': 'work go today and you just start having',
#   'start': 1838.279,
#   'duration': 4.321},
#  {'text': 'these wacky random Connections in your',
#   'start': 1840.2,
#   'duration': 4.479},
#  {'text': 'head and it can be really fun to watch I',
#   'start': 1842.6,
#   'duration': 3.72},
#  {'text': 'was doing it just as an entertainment',
#   'start': 1844.679,
#   'duration': 3.681},
#  {'text': 'thing the an exploratory thing what have',
#   'start': 1846.32,
#   'duration': 4.359},
#  {'text': "you found out I'm not looking to find",
#   'start': 1848.36,
#   'duration': 4.159},
#  {'text': "anything so I think that's part of",
#   'start': 1850.679,
#   'duration': 2.961},
#  {'text': 'curiosity you have to be a little',
#   'start': 1852.519,
#   'duration': 2.801},
#  {'text': 'careful because if you go looking for',
#   'start': 1853.64,
#   'duration': 3.24},
#  {'text': "something in particular then you're only",
#   'start': 1855.32,
#   'duration': 3.079},
#  {'text': "open to seeing that thing and that's not",
#   'start': 1856.88,
#   'duration': 3.84},
#  {'text': "how you find anything that's true um but",
#   'start': 1858.399,
#   'duration': 4.52},
#  {'text': "it it's just pure mere curiosity it's",
#   'start': 1860.72,
#   'duration': 3.76},
#  {'text': "it's an entertaining State that's that's",
#   'start': 1862.919,
#   'duration': 3.6},
#  {'text': 'a fine reason to do it right we do',
#   'start': 1864.48,
#   'duration': 3.439},
#  {'text': 'everything because we enjoy it at the',
#   'start': 1866.519,
#   'duration': 2.441},
#  {'text': "end of the day if you didn't you",
#   'start': 1867.919,
#   'duration': 3.561},
#  {'text': "wouldn't do it right or you want to not",
#   'start': 1868.96,
#   'duration': 3.959},
#  {'text': 'NE enjoy it but you do it because you',
#   'start': 1871.48,
#   'duration': 4.199},
#  {'text': 'want to um so I did it just because I',
#   'start': 1872.919,
#   'duration': 5.64},
#  {'text': 'wanted to and once in a while once in a',
#   'start': 1875.679,
#   'duration': 4.24},
#  {'text': "while and I'm not trying to suggest",
#   'start': 1878.559,
#   'duration': 3.12},
#  {'text': 'anything because again if I suggest',
#   'start': 1879.919,
#   'duration': 3.12},
#  {'text': "something then it's not going to happen",
#   'start': 1881.679,
#   'duration': 4.201},
#  {'text': "for you but you know I'll basically feel",
#   'start': 1883.039,
#   'duration': 5.201},
#  {'text': "like I'm dying so I'm falling asleep but",
#   'start': 1885.88,
#   'duration': 3.96},
#  {'text': "I feel like I'm dying it's like you can",
#   'start': 1888.24,
#   'duration': 3.96},
#  {'text': 'see things fading out right and as you',
#   'start': 1889.84,
#   'duration': 5.52},
#  {'text': "fall asleep the the French uh no that's",
#   'start': 1892.2,
#   'duration': 5.64},
#  {'text': 'not they call orgasm the petite more The',
#   'start': 1895.36,
#   'duration': 5.319},
#  {'text': "Little Death right but uh but it's also",
#   'start': 1897.84,
#   'duration': 4.16},
#  {'text': 'because your mind shuts down right so',
#   'start': 1900.679,
#   'duration': 2.681},
#  {'text': "what's happening is your your mind is",
#   'start': 1902.0,
#   'duration': 3.12},
#  {'text': 'shutting down from waking to sleeping',
#   'start': 1903.36,
#   'duration': 3.679},
#  {'text': "State and that's kind of a death",
#   'start': 1905.12,
#   'duration': 3.72},
#  {'text': 'transition you can kind of feel like',
#   'start': 1907.039,
#   'duration': 5.201},
#  {'text': "you're dying and you can literally see",
#   'start': 1908.84,
#   'duration': 5.719},
#  {'text': 'thoughts going offline your mind goes',
#   'start': 1912.24,
#   'duration': 5.159},
#  {'text': 'offline and as your mind goes offline',
#   'start': 1914.559,
#   'duration': 5.24},
#  {'text': 'pay atten attention to what', 'start': 1917.399, 'duration': 5.321},
#  {'text': 'remains pay attention to what actually',
#   'start': 1919.799,
#   'duration': 5.041},
#  {'text': "remains and don't be afraid of it don't",
#   'start': 1922.72,
#   'duration': 4.24},
#  {'text': "be AF you're just falling asleep but",
#   'start': 1924.84,
#   'duration': 3.439},
#  {'text': 'like I said sometimes it feels like',
#   'start': 1926.96,
#   'duration': 3.559},
#  {'text': "you're dying and don't be afraid of",
#   'start': 1928.279,
#   'duration': 4.24},
#  {'text': 'death right you just kind of go with it',
#   'start': 1930.519,
#   'duration': 4.04},
#  {'text': "it's what's just what's happening and",
#   'start': 1932.519,
#   'duration': 4.961},
#  {'text': 'then as your mind disappears as things',
#   'start': 1934.559,
#   'duration': 4.801},
#  {'text': 'disappear as things Fade Out of',
#   'start': 1937.48,
#   'duration': 5.0},
#  {'text': "existence see what remains okay there's",
#   'start': 1939.36,
#   'duration': 5.439},
#  {'text': 'a version of something like this that I',
#   'start': 1942.48,
#   'duration': 4.6},
#  {'text': 'do for me the last two thoughts are',
#   'start': 1944.799,
#   'duration': 3.6},
#  {'text': 'always', 'start': 1947.08, 'duration': 4.92},
#  {'text': "the girl I'm seeing and or uh the God I",
#   'start': 1948.399,
#   'duration': 6.201},
#  {'text': 'know MH which is just Universal energy',
#   'start': 1952.0,
#   'duration': 4.12},
#  {'text': 'yeah these are all manifestations of',
#   'start': 1954.6,
#   'duration': 3.76},
#  {'text': 'what you would call love right this is',
#   'start': 1956.12,
#   'duration': 4.039},
#  {'text': 'this is you stop thinking about yourself',
#   'start': 1958.36,
#   'duration': 3.48},
#  {'text': 'because thoughts are what Drive the',
#   'start': 1960.159,
#   'duration': 3.4},
#  {'text': 'self- obsession the self is ultimately',
#   'start': 1961.84,
#   'duration': 4.12},
#  {'text': "just a thought it's a it's a the self is",
#   'start': 1963.559,
#   'duration': 4.12},
#  {'text': 'a thought that I am a separate creature',
#   'start': 1965.96,
#   'duration': 3.719},
#  {'text': "I'm a body I'm a mind and if you truly",
#   'start': 1967.679,
#   'duration': 3.72},
#  {'text': "were not thinking like you're in deep",
#   'start': 1969.679,
#   'duration': 3.6},
#  {'text': "meditation or you're on a psychedelic or",
#   'start': 1971.399,
#   'duration': 3.681},
#  {'text': "you're a Buddha you wouldn't have a",
#   'start': 1973.279,
#   'duration': 3.161},
#  {'text': 'thought of the self and you would just',
#   'start': 1975.08,
#   'duration': 4.04},
#  {'text': "be you just be be aware that's all",
#   'start': 1976.44,
#   'duration': 4.32},
#  {'text': "that's all there is I think the",
#   'start': 1979.12,
#   'duration': 3.08},
#  {'text': 'difference in your state of', 'start': 1980.76, 'duration': 4.039},
#  {'text': "consciousness and mine is one you're",
#   'start': 1982.2,
#   'duration': 4.16},
#  {'text': "much older and you've seen life and by",
#   'start': 1984.799,
#   'duration': 3.88},
#  {'text': 'older I mean brain older not physical',
#   'start': 1986.36,
#   'duration': 5.159},
#  {'text': "body older you're a wiser human being",
#   'start': 1988.679,
#   'duration': 4.201},
#  {'text': "and I think over the years you've just",
#   'start': 1991.519,
#   'duration': 3.52},
#  {'text': 'learned to observe and pick up data from',
#   'start': 1992.88,
#   'duration': 4.799},
#  {'text': 'everywhere U my early life experiences',
#   'start': 1995.039,
#   'duration': 4.76},
#  {'text': 'kind of catered me towards a deep sense',
#   'start': 1997.679,
#   'duration': 4.88},
#  {'text': 'of what we call bti in India which is uh',
#   'start': 1999.799,
#   'duration': 5.961},
#  {'text': 'nisat prame or unselfish love towards',
#   'start': 2002.559,
#   'duration': 5.0},
#  {'text': "the Divine it's just an outcome of",
#   'start': 2005.76,
#   'duration': 4.68},
#  {'text': 'living in India in my eyes yeah no I I',
#   'start': 2007.559,
#   'duration': 5.801},
#  {'text': 'what matters is truth not who says what',
#   'start': 2010.44,
#   'duration': 5.359},
#  {'text': 'or what where you lived or what book you',
#   'start': 2013.36,
#   'duration': 4.52},
#  {'text': "read what just matters is what's true",
#   'start': 2015.799,
#   'duration': 3.681},
#  {'text': 'and that you can figure out for yourself',
#   'start': 2017.88,
#   'duration': 2.88},
#  {'text': 'and you can figure it out just as well',
#   'start': 2019.48,
#   'duration': 3.079},
#  {'text': 'as me and you probably have your your',
#   'start': 2020.76,
#   'duration': 4.72},
#  {'text': 'core experience of of your awareness',
#   'start': 2022.559,
#   'duration': 5.84},
#  {'text': 'same as mine every emotion you felt I',
#   'start': 2025.48,
#   'duration': 4.799},
#  {'text': "felt every emotion I felt you felt we're",
#   'start': 2028.399,
#   'duration': 4.561},
#  {'text': 'human no Human Experience is alien to us',
#   'start': 2030.279,
#   'duration': 5.041},
#  {'text': 'so we can have all the same feelings and',
#   'start': 2032.96,
#   'duration': 3.719},
#  {'text': 'thoughts just in different levels and',
#   'start': 2035.32,
#   'duration': 4.16},
#  {'text': 'different bases um i s i s I sort of',
#   'start': 2036.679,
#   'duration': 4.441},
#  {'text': "reject this idea that I'm Wiser or more",
#   'start': 2039.48,
#   'duration': 3.559},
#  {'text': "advanced I don't think that's true no if",
#   'start': 2041.12,
#   'duration': 4.72},
#  {'text': "I was wise I'd be a Buddha I'm not so",
#   'start': 2043.039,
#   'duration': 4.561},
#  {'text': "it's like you know two ants debating",
#   'start': 2045.84,
#   'duration': 4.079},
#  {'text': "like you know who's smarter and there's",
#   'start': 2047.6,
#   'duration': 3.519},
#  {'text': "like a there's like a human walking",
#   'start': 2049.919,
#   'duration': 4.321},
#  {'text': 'around over there right what ises it',
#   'start': 2051.119,
#   'duration': 5.641},
#  {'text': 'matter okay not in our eyes because for',
#   'start': 2054.24,
#   'duration': 4.599},
#  {'text': 'a lot of dudes in their 20s and 30s you',
#   'start': 2056.76,
#   'duration': 4.399},
#  {'text': 'are what we want to become especially',
#   'start': 2058.839,
#   'duration': 4.52},
#  {'text': "from a peace perspective I'm the same",
#   'start': 2061.159,
#   'duration': 3.68},
#  {'text': "guy I've always been and I wouldn't even",
#   'start': 2063.359,
#   'duration': 4.0},
#  {'text': "say I'm that peaceful my mind is a wreck",
#   'start': 2064.839,
#   'duration': 4.28},
#  {'text': "really yeah I'm always like my mind's",
#   'start': 2067.359,
#   'duration': 3.24},
#  {'text': "always running all over the place it's",
#   'start': 2069.119,
#   'duration': 3.24},
#  {'text': "it's it's always active you know how you",
#   'start': 2070.599,
#   'duration': 3.921},
#  {'text': 'said that happiness is peace and motion',
#   'start': 2072.359,
#   'duration': 4.04},
#  {'text': "mhm uh that's something that stayed with",
#   'start': 2074.52,
#   'duration': 3.559},
#  {'text': "me over the years and it's something I",
#   'start': 2076.399,
#   'duration': 3.321},
#  {'text': "practiced the the person who's going to",
#   'start': 2078.079,
#   'duration': 3.161},
#  {'text': 'know the most about weight loss is the',
#   'start': 2079.72,
#   'duration': 3.399},
#  {'text': 'person who was fat as a kid the person',
#   'start': 2081.24,
#   'duration': 3.32},
#  {'text': "who's going to know the most about peace",
#   'start': 2083.119,
#   'duration': 2.681},
#  {'text': 'and happiness is the one who was the',
#   'start': 2084.56,
#   'duration': 4.76},
#  {'text': "most miserable inside so don't take from",
#   'start': 2085.8,
#   'duration': 5.24},
#  {'text': "anything I write to say that I'm some",
#   'start': 2089.32,
#   'duration': 3.599},
#  {'text': "peaceful Zen Buddha inside I'm not my",
#   'start': 2091.04,
#   'duration': 3.4},
#  {'text': "mind still runs out of control it's I'm",
#   'start': 2092.919,
#   'duration': 3.96},
#  {'text': "a crazy person I'm a I'm a crazy person",
#   'start': 2094.44,
#   'duration': 3.88},
#  {'text': "who's trying to be a little less crazy",
#   'start': 2096.879,
#   'duration': 3.161},
#  {'text': 'and observing my own craziness that',
#   'start': 2098.32,
#   'duration': 3.039},
#  {'text': "that's how I can come back to you and",
#   'start': 2100.04,
#   'duration': 3.92},
#  {'text': 'say like you know when I started',
#   'start': 2101.359,
#   'duration': 5.201},
#  {'text': 'tweeting a lot uh about anything other',
#   'start': 2103.96,
#   'duration': 4.48},
#  ...]

# %% [markdown]
# #### step 1(b) Text Splitting

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size = 1000 , chunk_overlap=200)
chunk = splitter.create_documents([transcript])

# %%
len(chunk)
# Out:
# 134

# %%
chunk[2]
# Out:
# Document(metadata={}, page_content="have this impression of Naval rikan the brand and the human and I feel like nothing hurts that guy I'm a very paranoid person so my rule is I don't fight with people if somebody wants to fight with me we get one fight and then it's over there's a lot of people out there and life is long do you pray if you are older in life and you don't have the Next Generation to look forward to then you better find God fast because I don't think like your own mind and your own life will be kind to you as you get older if you know who Naval ravikant is please head straight into the conversation this intro is primarily crafted for those of you who are being introduced to Naval ravikant for the first time surprisingly there's a lot of people in India who are yet to be introduced to who I consider to be the greatest philosopher of our times I genuinely believe that history will remember him as one of the greatest Minds that lived in the 21st century he's an extremely humble extremely relaxed individual")

# %% [markdown]
# #### step 1(c) Vector Storing

# %%
embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')  
vector_store = FAISS.from_documents(chunk, embeddings)

# %%
vector_store.index_to_docstore_id
# Out:
# {0: '6bc7329f-060c-43d4-b8e4-b04d895947e8',
#  1: 'e88df3d7-d61b-4465-9188-ea38e7ff1b02',
#  2: '0765435a-ba39-41c5-8514-41b72c670ccc',
#  3: 'ae3d00f4-ccdb-4eff-b126-b316095541c3',
#  4: 'c441c67b-c6b7-4686-9a33-23a328a9b95b',
#  5: '4da042d7-2685-4ccc-8d73-11b58be8dcb1',
#  6: '884b3f41-458e-4e50-8e10-0c8d0df7b890',
#  7: '8f378ded-3a1e-4463-8595-86a6d6ef4717',
#  8: '36560e2e-f54a-4411-9ef5-6653fc141f21',
#  9: '5461818d-fd38-4e01-b2c2-44fcd511a0a9',
#  10: '3c687a10-64ca-4e54-a3b2-6911da948625',
#  11: 'f79bb246-bd1e-45f5-8619-6af40e6125ef',
#  12: '62616645-7cdc-4fa1-b2bc-d35bbc96d858',
#  13: '9c3a0a58-935b-4f6b-8a77-45a735ed1acd',
#  14: '378725f6-c51e-463e-894e-767d5a174310',
#  15: '6327b965-71ab-4767-8d18-4460c914788a',
#  16: '6729455b-eb66-42a8-bc11-964a575c5d8d',
#  17: '79e7c994-f855-4433-992e-ed3dd68a7dfa',
#  18: '3173ecdd-4f9e-428d-8e51-29abe7fbca11',
#  19: 'bea93357-6153-418d-84ad-5c545555ebdd',
#  20: '8426d296-0067-460c-9c55-b59d9f459caf',
#  21: 'aa9c66dc-543d-492e-ba9f-7620a593b125',
#  22: '1008ca99-1bf2-4efb-b63c-deeff107ef56',
#  23: '7c3cf91c-ae96-4bcc-bf8d-9e8a5e005ae1',
#  24: 'c41ad734-a8d0-480b-aa89-ee9f5393153f',
#  25: '4eadb18d-f0b9-4b77-9eac-18e9faf63e0c',
#  26: '49ea54ac-59b0-4829-8f52-9c476f027177',
#  27: '2073691d-05a2-4044-815f-3d82290fea69',
#  28: '3a7e5fed-51d9-4f5f-b02e-37d91b7ab17c',
#  29: '076edc33-f652-4199-8525-9c40fe2c5143',
#  30: '9103153e-8c5d-451f-af51-19ba9c958fbb',
#  31: 'c0095d45-f49e-4639-a3b8-93bdb003cd39',
#  32: '189b34f5-7353-404a-be3d-9988e8e91131',
#  33: '86da7c4c-9260-4ee9-a058-beb9cd9ccfb5',
#  34: 'd713ae8f-4e4d-4257-89fa-63569648e52a',
#  35: 'c00acf61-fb31-43ad-9935-72273748b1d4',
#  36: '0753b8f4-d3c3-4ea2-8bcd-080ed76da689',
#  37: 'ab87d479-e484-45f3-94cb-3ef4fed48aeb',
#  38: '1899aecc-9509-4fef-a739-c68adb4fa1ad',
#  39: '00e868de-8bb6-419a-b922-2136908e2fe2',
#  40: '790846ec-1e8e-4eaa-844c-3e2036852ef3',
#  41: '1aeb827e-e5dc-4cb5-a0fc-f6c339d9fa5d',
#  42: '8a7448a9-158a-40f8-8b8a-ed4f6217ee60',
#  43: 'e78d2c86-f1c7-4eb0-a253-cc7f05d89b87',
#  44: 'c11d9d89-2774-4802-9d2f-1b84d2dafdf0',
#  45: '6c43ecf0-b21f-4cf7-89d8-d6012d3abe96',
#  46: '823ae02b-3095-41ca-9eaa-0d3eb45d97cf',
#  47: '7fa7ece5-1139-4697-8b21-409214080a9c',
#  48: '8cd3bed3-35df-4247-9c69-30fe4fd78de1',
#  49: 'c7a5b45f-60e6-40fd-8a4a-8f337038d0bd',
#  50: '690b0ba7-e6df-41c2-a5e2-fbd17cdb4def',
#  51: '4f2461b0-c414-42f9-88f2-ccd032805baf',
#  52: 'ecf37c5e-8123-41f7-bd26-22567672a572',
#  53: '8e4ea45f-681e-40d2-a25f-128f3466c422',
#  54: '7321ebc0-ceca-4fe0-a4a1-2028274c6a9e',
#  55: 'e2b47335-e7da-4aa4-817a-e8f249c4fcbb',
#  56: '44e788ed-f0a3-4ad6-91da-d02136076f4a',
#  57: 'adfb528b-6bb4-4af2-a308-8e4697b09f26',
#  58: '298ffaae-fb18-43d5-8a2f-608d545f5858',
#  59: '8126c458-84cd-4c13-93c4-c07b605771fa',
#  60: 'eaabfc90-13c5-4f9b-ab91-ff799dc33195',
#  61: '4aa9487b-b593-4d89-a1fe-49af3eaa1354',
#  62: '18d265bf-5ba1-4ee1-a586-4c8c7f3a8e28',
#  63: 'aca6ed4e-e44a-4712-9074-34dd10350e72',
#  64: '85ec59a1-6f3f-4be8-8f70-c2f713da359c',
#  65: '4c3dbd69-cd89-4edb-ba39-059acde02a5c',
#  66: '3e52aadf-e113-43ed-b323-0d2873d8309e',
#  67: '65a6ab05-b2fb-46d5-8812-1faa27037cd3',
#  68: '43e71b72-9d00-4954-b415-eff0d913ff51',
#  69: '33842cb5-2ae7-4dd5-a10d-daa8780374e8',
#  70: '9da6fcb5-2385-4222-8dd7-b8b27d98fa10',
#  71: '26049d91-a335-4cae-9446-693ea436fbcb',
#  72: '77cf7b85-6d2a-4912-8e89-f844d72a9bc0',
#  73: '5d22fe0e-cb1a-4eb1-a2ae-211d35a42c04',
#  74: 'f4a6e669-f04f-4348-a970-ef030cad4501',
#  75: '2d094d3a-14a0-4f76-bd8c-712d65441e6c',
#  76: '2d500db5-00ab-4e93-a42f-762438181b17',
#  77: '80e0c09d-57c2-419b-b6e6-ef16ab19a277',
#  78: 'e513855a-542f-4652-892f-74ab212c1314',
#  79: '2c55a12f-bb4f-490d-94cb-8ff1b06473e8',
#  80: 'a2a91b22-c425-494a-8027-5ebf9aaa14b6',
#  81: '1316784a-89c3-4588-aacd-e716a3d236ce',
#  82: 'c374ced6-e987-46a1-beb1-442c80c86ffc',
#  83: '130a52cc-349d-4435-b2d6-72662aa43838',
#  84: '5c5baee4-689e-4940-9051-b86a9f1826d5',
#  85: 'f5e0d4fe-7f0a-440d-bc23-77c345b8920e',
#  86: '1d186fc9-4020-49d7-ad23-28544ed42f9c',
#  87: '6c4cc1bd-8e60-4a09-9ec7-2ba1922879f0',
#  88: '94d4be5a-f027-4175-9e44-49db80a1dc7a',
#  89: '377b1fbb-e653-4494-a90d-888bae21c4f4',
#  90: '9f01c46b-144b-407b-9cf7-adc46098d5ab',
#  91: 'ad354330-ed80-4247-bab6-a0ec3b03a1d8',
#  92: '1743912d-f25d-4c6e-a54c-14b51264c45d',
#  93: '772846e3-9d98-412d-9eda-cea765fe50c9',
#  94: '736fbf9b-90db-43f2-a030-2acc3d36e2c2',
#  95: 'c071e8b5-9226-43b6-8bd0-ca036e7d1fc4',
#  96: 'c62f09dd-db5f-4456-b28f-c845ff546b35',
#  97: '3067fad1-ad0a-40f4-9531-5205a6fcac98',
#  98: 'f3676ae9-e066-4016-96e5-2165c00cf14f',
#  99: 'a0e2abc8-1392-4540-9f3d-a8314eae2dbc',
#  100: 'ffcfe5dc-a43c-4c76-abca-88697c44ebb2',
#  101: 'deb340b2-69df-4cef-828a-4baebc92f0c7',
#  102: '7c9ece9a-0367-478c-bb02-26feeeb4db8f',
#  103: '85b23b45-089a-4161-9602-fa799c5d6f64',
#  104: '1718c4d5-c506-4fcb-b327-5053a2da30bf',
#  105: 'ee1b5f74-ea7c-4a5e-ba4a-2ccfa7b178f2',
#  106: 'e92c7ced-ed05-490a-8c97-d63923179400',
#  107: 'c11cb8c2-a4c7-406c-b15b-7545c33aaa64',
#  108: 'bf1fce2d-6d42-41c3-98ef-673facf39b0f',
#  109: '1769af6f-01bc-4329-a4eb-c4c6892ffd96',
#  110: 'edfb628b-8d51-4263-a244-14e925fa8a39',
#  111: '7772a417-4445-4113-b858-f6a3795d294f',
#  112: '05543181-f951-4c69-a548-fcc622b3ba08',
#  113: '21e3884a-4f67-4457-b32b-817bc8366b5a',
#  114: 'a2996ad7-3110-4690-856a-fde0746b164c',
#  115: '126a61db-917c-45e9-8a8f-d2ed49e8eac8',
#  116: 'f2d3d023-85d2-40c1-9ca4-e03199ed0434',
#  117: '97178549-45d8-4269-9803-c4a8dbc3f957',
#  118: '588b1cd5-5128-45e7-8624-238e5e5be9dc',
#  119: '5e77aeea-07df-4558-9e64-0ae50e59493e',
#  120: 'e5da0549-5843-48bb-8245-b5409e0d27aa',
#  121: '6337b870-873d-4405-ad02-a668c0308312',
#  122: '95d3ee0c-6018-40f4-bad2-693c826d749c',
#  123: '62d588d8-4e4b-4110-b9b8-611b20221231',
#  124: '2fa6ef38-2c93-4195-9956-9006b5ff89aa',
#  125: 'fef070d9-3a7a-493a-9d56-b361d849f1ca',
#  126: 'd022a525-8b4b-4f5e-9ff0-758443cbee82',
#  127: '2bd39c23-361d-4eec-b845-eb64a65ed6a2',
#  128: '40e5a6c1-c172-4f4f-bce8-d279cfe39c7d',
#  129: '2f03d699-bf52-44ed-bd2a-ecfdc86c8f25',
#  130: 'f179d940-07f3-41e1-a3c9-ab3d09c94313',
#  131: 'bacd5015-66e2-4888-a24c-317bb0e100ad',
#  132: '9de93aa8-d24a-42ec-8167-d10529c7bb06',
#  133: '5ad1386d-2ceb-4f9e-a242-c532aa747b6b'}

# %%
vector_store.get_by_ids(['6bc7329f-060c-43d4-b8e4-b04d895947e8'])
# Out:
# [Document(id='6bc7329f-060c-43d4-b8e4-b04d895947e8', metadata={}, page_content="this was one of the biggest days of my podcasting career that's the magic of naal ravikant Nal rant Nal ravikant founder of Angel Del no rikan Naro rakan the founder of angelist which is a giant business I mean Global I I wonder if you've ever thought of that reality if your parents didn't leave India and go to the US how would your life be different according to you the first time I used an Apple computer it was an old Macintosh I just fell in love with it at some point if you have high agency you will end up where you're meant to go it's just going to take some effort did it do anything for your mind I kind of sometimes have these near-death exercises where it's just like I imagine myself dying it's like you can see things fading out they call orgasm the petite more The Little Death right did you ever smoke weed you know I live in California well the common belief now is that like mushrooms are harmless right they're not do you miss your childhood I don't have a it's like a dream is")]

# %% [markdown]
# #### step 2 Retrieval

# %%
retriever = vector_store.as_retriever(search_type="similarity",search_kwargs={"k":4})

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'HuggingFaceEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x000002238D6CF1A0>, search_kwargs={'k': 4})

# %%
retriever.invoke('who is naval?')
# Out:
# [Document(id='0765435a-ba39-41c5-8514-41b72c670ccc', metadata={}, page_content="have this impression of Naval rikan the brand and the human and I feel like nothing hurts that guy I'm a very paranoid person so my rule is I don't fight with people if somebody wants to fight with me we get one fight and then it's over there's a lot of people out there and life is long do you pray if you are older in life and you don't have the Next Generation to look forward to then you better find God fast because I don't think like your own mind and your own life will be kind to you as you get older if you know who Naval ravikant is please head straight into the conversation this intro is primarily crafted for those of you who are being introduced to Naval ravikant for the first time surprisingly there's a lot of people in India who are yet to be introduced to who I consider to be the greatest philosopher of our times I genuinely believe that history will remember him as one of the greatest Minds that lived in the 21st century he's an extremely humble extremely relaxed individual"),
#  Document(id='ae3d00f4-ccdb-4eff-b126-b316095541c3', metadata={}, page_content="greatest philosopher of our times I genuinely believe that history will remember him as one of the greatest Minds that lived in the 21st century he's an extremely humble extremely relaxed individual so I know that this intro is going to bother him on some level that's the side of Naval that I got to know through this conversation this is the most casual conversation that the internet has ever seen with this man it was one of the biggest honors of my own podcasting career to be sharing screen space and podcasting space with Naval ravikant if I had to introduce him professionally of course I'd tell you how he's one of the most iconic Angel Investors in the world of course i' tell you about how he's one of the most important thought leaders for Silicon Valley and the world of Global Twitter or X it's Naval ravikant on the RV show this is one of the most memorable episodes for me on a personal level but if you're looking for depth in conversation it doesn't get deeper than Naval rikan's"),
#  Document(id='c441c67b-c6b7-4686-9a33-23a328a9b95b', metadata={}, page_content="or X it's Naval ravikant on the RV show this is one of the most memorable episodes for me on a personal level but if you're looking for depth in conversation it doesn't get deeper than Naval rikan's mind it's Naval on TRS huge day for my career honestly huge day for my own Human Experience enjoy the [Music] episode this is one of the biggest days of my podcasting career but I'm also feeling supremely comfortable that's the magic of Nel ravian oh you're very nice welcome to the ren show sir thank you thanks for having me uh visualize this moment so much over the years so as I told you in the car ride on the way here uh I'm full of gratitude and as we go forward in this conversation I'm going to pour more and more gratitude on you uh when we were on our way here from the network state conference I saw how much you were hounded uh people just want to come up and say that they love you uh this takes me back to that Joe Rogan episode you did in 2019 are you aware of how many young men's"),
#  Document(id='884b3f41-458e-4e50-8e10-0c8d0df7b890', metadata={}, page_content="we really figure out ourselves right there's like there there's what are the different kinds of knowledge this weth thinking through right I'm just thinking it through with you so there's Knowledge from direct experience right you experience something and that generates knowledge inside of you there's knowledge that you pick up from other sources you just a vessel that's passing through you you picked it up you synthesize it you regurgitate there's uh knowledge that you create which is rare um um I don't know if I said anything original really yeah I don't know I don't know but I think you accumulated a lot of data which is back by years of reading and research I think if I were to look back I would say that the only true knowledge I have is the knowledge that is uh directly verified by me and uh fits in with the other pieces so I view myself as a very basic thinker really yeah I don't view myself as an advanced thinker I'm not an expert in anything but what I like to do is everything")]

# %% [markdown]
# #### step3 Augmentation

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    google_api_key=os.getenv("GOOGLE_API_KEY")
)

# %%
prompt = PromptTemplate(
    template = 
    """ you are a helpful assistant. 
        Answer Only from the provided context.
        If the context is insufficient, just say you don't know.
        {context}
        Question: {question}
        """,
    input_variable = ['context','question']
)

# %%
question = "is the topic of spirituality is discussed in the video ? if yes then what was discussed"
retrieved_docs = retriever.invoke(question)

# %%
context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)

# %%
final_prompt = prompt.invoke({"context": context_text, "question":question})

# %% [markdown]
# #### step4 Generation

# %%
answer = llm.invoke(final_prompt)
print(answer.content)
# Out:
# Yes, the topic of spirituality is discussed.  The speaker mentions reading books like the Autobiography of a Yogi and the life of the Buddha, and watching videos of various spiritual teachers.  They discuss different paths to enlightenment, questioning whether there's a single "right" way, and ultimately concluding that one must figure it out for themselves.  The speaker also touches upon the meaning of life, the nature of miracles, and the impact of one's upbringing on their spiritual perspective.

# %% [markdown]
# #### step5 Chain

# %%
from langchain_core.runnables import RunnableParallel, RunnableLambda, RunnableMap
from langchain_core.output_parsers import StrOutputParser

# %%
def format_docs(retrieved_docs):
    context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)
    return context_text

# %%
parallel_chain = RunnableParallel({
    "context": RunnableLambda(lambda x: x["question"]) | retriever | RunnableLambda(format_docs),
    "question": RunnableLambda(lambda x: x["question"])
})

# %%
result = parallel_chain.invoke({"question": "who is naval ravikant"})
print(result)
# Out:
# {'context': "have this impression of Naval rikan the brand and the human and I feel like nothing hurts that guy I'm a very paranoid person so my rule is I don't fight with people if somebody wants to fight with me we get one fight and then it's over there's a lot of people out there and life is long do you pray if you are older in life and you don't have the Next Generation to look forward to then you better find God fast because I don't think like your own mind and your own life will be kind to you as you get older if you know who Naval ravikant is please head straight into the conversation this intro is primarily crafted for those of you who are being introduced to Naval ravikant for the first time surprisingly there's a lot of people in India who are yet to be introduced to who I consider to be the greatest philosopher of our times I genuinely believe that history will remember him as one of the greatest Minds that lived in the 21st century he's an extremely humble extremely relaxed individual\n\ngreatest philosopher of our times I genuinely believe that history will remember him as one of the greatest Minds that lived in the 21st century he's an extremely humble extremely relaxed individual so I know that this intro is going to bother him on some level that's the side of Naval that I got to know through this conversation this is the most casual conversation that the internet has ever seen with this man it was one of the biggest honors of my own podcasting career to be sharing screen space and podcasting space with Naval ravikant if I had to introduce him professionally of course I'd tell you how he's one of the most iconic Angel Investors in the world of course i' tell you about how he's one of the most important thought leaders for Silicon Valley and the world of Global Twitter or X it's Naval ravikant on the RV show this is one of the most memorable episodes for me on a personal level but if you're looking for depth in conversation it doesn't get deeper than Naval rikan's\n\nor X it's Naval ravikant on the RV show this is one of the most memorable episodes for me on a personal level but if you're looking for depth in conversation it doesn't get deeper than Naval rikan's mind it's Naval on TRS huge day for my career honestly huge day for my own Human Experience enjoy the [Music] episode this is one of the biggest days of my podcasting career but I'm also feeling supremely comfortable that's the magic of Nel ravian oh you're very nice welcome to the ren show sir thank you thanks for having me uh visualize this moment so much over the years so as I told you in the car ride on the way here uh I'm full of gratitude and as we go forward in this conversation I'm going to pour more and more gratitude on you uh when we were on our way here from the network state conference I saw how much you were hounded uh people just want to come up and say that they love you uh this takes me back to that Joe Rogan episode you did in 2019 are you aware of how many young men's\n\nvery important life moment for me it's something I've visualized for a very long time before we executed upon this podcast uh dream come true for anyone who's been listening to podcasts for the last decade we all know what a big deal naal ravikant is I'm just glad I got to do this very easygoing conversation with him and I hope that he returns on the renv show at some point in the future I will be attaching all his social handles down below so for those of you who are being introduced to him for the first time please go follow Nel ravikant on every social media platform I also urge you to pick up Snippets from this conversation and turn them into reels and shots for social media thank you for listening in DRS and the whole team we'll be back very very soon [Music]", 'question': 'who is naval ravikant'}

# %%
parser = StrOutputParser()

# %%
main_chain = parallel_chain | prompt | llm | parser

# %%
main_chain.invoke({"question": "can you summarize the video"})
# Out:
# 'The speaker discusses the creation of a podcast episode, emphasizing its significance as the first international episode shot in Singapore.  They also reflect on their spiritual journey, mentioning explorations into various spiritual teachings and practices, including those of Krishna, and the ultimately personal nature of enlightenment.  The speaker concludes by referencing the children\'s song "Row, Row, Row Your Boat" as a metaphor for life\'s journey, highlighting its simplicity and wisdom.'
